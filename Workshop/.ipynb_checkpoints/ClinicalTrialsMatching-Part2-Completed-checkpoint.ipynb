# %% [markdown]
# # Unimportant settings

# %%
# This setting allows the notebook to show all 
# outputs instead of only the last one. It's just a QoL thing.
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # Import packages
#
# This is where we will import our **Python tools** that will help us tackle this problem

# %%
import pandas as pd # to read and analyse data

# %% [markdown]
# # Import the data

# %%
clinical_trials_data_path = 'https://raw.githubusercontent.com/vohcolab/TREC-Clinical-Workshop/main/data/sample_collection.csv'
patients_data_path = 'https://raw.githubusercontent.com/vohcolab/TREC-Clinical-Workshop/main/data/patients_sample.csv'


clinical_trials_data = pd.read_csv(clinical_trials_data_path,index_col=0)
patients_data = pd.read_csv(patients_data_path,index_col=0)

# %% [markdown]
# ## Continuing from where we left off

# %% [markdown]
# Out of all requirements, probably matching the gender and age are the easiest ones to complete. Let's solve the gender matching then!

# %% [markdown]
# <img src="https://i.imgflip.com/1yuocg.jpg">

# %%
# let's save the patient description under the variable 'text'
text = patients_data.iloc[19].description
text
# Out:
# 'A 72-year-old man complains of increasing calf pain when walking uphill. The symptoms have gradually increased over the past 3 months. The patient had an uncomplicated myocardial infarction 2 years earlier and a transient ischemic attack 6 months ago. Over the past month, his blood pressure has worsened despite previous control with diltiazem, hydrochlorothiazide, and propranolol. His is currently taking isosorbide dinitrate, hydrochlorothiazide, and aspirin. On physical examination, his blood pressure is 151/91 mm Hg, and his pulse is 67/min. There is a right carotid bruit. His lower extremities are slightly cool to the touch and have diminished pulses at the dorsalis pedis.\n        '

# %%
def naive_gender_detector(text):
    """
    This function (tries to) detect the gender of the patient
    given their medical description.
    """
    
    possible_male_references =  ['male','man','boy']
    
    for reference in possible_male_references:
        position_found = text.find(reference)
        
        if position_found == -1:
            continue
        else:
            return 'Male'
    return 'Female'

# %%
naive_gender_detector(text)
# Out:
# 'Male'

# %% [markdown]
# Awesome! It works for this example. But does it work for all examples?

# %%
sneaky_female_text = patients_data.iloc[25].description
sneaky_female_text
# Out:
# 'A 43-year-old woman visits her dermatologist for lesions on her neck. On examination, multiple lesions are seen. Each lesion is small soft, and pedunculated. The largest lesion is about 4 mm in diameter. The color of different lesions varies from flesh colored to slightly hyperpigmented.\n        '

# %% [markdown]
# Now we just need to call our gender detection function!

# %% [markdown]
# <img src="https://i.imgflip.com/5ds971.jpg" width="600">

# %%
naive_gender_detector(sneaky_female_text)
# Out:
# 'Male'

# %% [markdown]
# <img src="https://memegenerator.net/img/instances/62594221.jpg" width="300">

# %% [markdown]
# Wel... this is awkward

# %% [markdown]
# > Can you figure out why this happened?

# %%
def naive_gender_detector_slightly_improved(text):
    """
    This function (tries to) detect the gender of the patient
    given their medical description.
    """
    
    possible_male_references =  [' male ', ' man ','boy']
    
    for reference in possible_male_references:
        position_found = text.find(reference)
        
        if position_found == -1:
            continue
        else:
            return 'Male'
    return 'Female'

# %%
naive_gender_detector_slightly_improved(sneaky_female_text)
# Out:
# 'Female'

# %% [markdown]
# <img src="https://i.imgflip.com/5dsbfs.jpg" width="500">

# %%
hidden_male_text = patients_data.iloc[-1].description
hidden_male_text
# Out:
# 'A 10 year old child is brought to the emergency room complaining of myalgia, cough, and shortness of breath.  Two weeks ago the patient was seen by his pediatrician for low-grade fever, abdominal pain, and diarrhea, diagnosed with a viral illness, and prescribed OTC medications. Three weeks ago the family returned home after a stay with relatives on a farm that raises domestic pigs for consumption. Vital signs: T: 39.5 C, BP: 90/60 HR: 120/min RR: 40/min. Physical exam findings include cyanosis,  slight stiffness of the neck,  and  marked periorbital edema. Lab results include WBC 25,000, with 25% Eosinophils, and an unremarkable urinalysis.\n        '

# %%
naive_gender_detector_slightly_improved(hidden_male_text)
# Out:
# 'Female'

# %% [markdown]
# <img src="https://wompampsupport.azureedge.net/fetchimage?siteId=7575&v=2&jpgQuality=100&width=700&url=https%3A%2F%2Fi.kym-cdn.com%2Fentries%2Ficons%2Foriginal%2F000%2F006%2F725%2FDesk_Flip_banner.jpg">

# %% [markdown]
# Trying to improve our system further than this becomes exponentially more complicated because we are trying to make the computer understand natural language, which is impossible... right? More on that later!
#
#
# For now let's finish our gender matching.

# %%
patients_data['infered_gender'] = patients_data.description.apply(naive_gender_detector_slightly_improved)
patients_data
# Out:
#                                                   description infered_gender
# patient_id
# 20141       A 58-year-old African-American woman presents ...         Female
# 201410      A physician is called to see a 67-year-old wom...         Female
# 201411      A 40-year-old woman with no past medical histo...         Female
# 201412      A 25-year-old woman presents to the clinic com...         Female
# 201413      A 30-year-old generally healthy woman presents...         Female
# 201414      An 85-year-old man is brought to the ER becaus...           Male
# 201415      A 36-year-old woman presents to the emergency ...         Female
# 201416      A 28-year-old female with neck and shoulder pa...         Female
# 201417      A 48-year-old white male with history of commo...           Male
# 201418      A 6-month-old male infant has a urine output o...           Male
# 20142       An 8-year-old male presents in March to the ER...           Male
# 201421      A 21-year-old female is evaluated for progress...         Female
# 201422      A 15-year-old girl presents to the ER with abd...         Female
# 201423      A 63-year-old man presents with cough and shor...           Male
# 201424      A 33-year-old male athlete presented to the ER...           Male
# 201426      A group of 14 humanitarian service workers is ...         Female
# 201427      A 21-year-old college student undergoes colono...         Female
# 201429      A 51-year-old woman is seen in clinic for advi...         Female
# 20143       A 58-year-old nonsmoker white female with mild...         Female
# 201430      A 72-year-old man complains of increasing calf...           Male
# 20144       A 2-year-old boy is brought to the emergency d...           Male
# 20145       A 56-year-old female on 20th day post-left mas...         Female
# 20146       64-year-old obese female with diagnosis of dia...         Female
# 20147       A 26-year-old obese woman with a history of bi...         Female
# 20148       A 62-year-old man sees a neurologist for progr...           Male
# 20149       A 43-year-old woman visits her dermatologist f...         Female
# 20151       A 44 yo male is brought to the emergency room ...           Male
# 201510      A 38 year old woman complains of severe premen...         Female
# 201511      A 56-year old Caucasian female complains of be...         Female
# 201512      A 44-year-old man was recently in an automobil...           Male
# 201513      A 5-year-old boy presents to the emergency dep...           Male
# 201516      A 4 year old boy presents to the emergency roo...           Male
# 201517      A 32 year old female with no previous medical ...         Female
# 201518      A 65 yo African-American male with shortness o...           Male
# 20152       A 62 yo male presents with four days of non-pr...           Male
# 201520      An 89-year-old man was brought to the emergenc...           Male
# 201521      A 32-year-old male presents to your office com...           Male
# 201523      An 18-year-old male returning from a recent va...           Male
# 201524      A 31 yo male with no significant past medical ...           Male
# 201525      A 10-year-old boy comes to the emergency depar...           Male
# 201527      A 15 yo girl accompanied by her mother is refe...         Female
# 201528      A previously healthy 8-year-old boy presents w...           Male
# 201529      A 4-year-old girl presents with persistent fev...         Female
# 20153       A 65 yo male with no significant history of ca...           Male
# 201530      A 47 year old male who fell on his outstretche...           Male
# 20154       An 82-year-old woman comes to the emergency de...         Female
# 20155       A 31-year-old woman with no previous medical p...         Female
# 20156       A 46-year-old woman presents  with a 9 month h...         Female
# 20157       A 20 yo female college student with no signifi...         Female
# 20158       A 10 yo boy with nighttime snoring, pauses in ...           Male
# 20159       A 10 year old child is brought to the emergenc...         Female

# %%
matching_data = {}

# iterate each clinical trial
for _,ct in clinical_trials_data.iterrows():
    
    # If the gender requirement is for both
    if ct['gender'] == 'Both':
        # all patients are eligible
        # match this trial with all of the patients
        matching_patients = patients_data.index.tolist()
    
    # But if it requires males
    elif ct['gender'] == 'Male':
        # match only with male patients
        matching_patients = patients_data[patients_data['infered_gender'] == 'Male'].index.tolist()
    else:
        # likewise for female patients
        matching_patients = patients_data[patients_data['infered_gender'] == 'Female'].index.tolist()
    # save this matching on our variable <matching_data>
    matching_data[ct.name] = matching_patients

# %%
matching_data
# Out:
# {'NCT00000408': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00000492': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00000501': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00001853': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00004727': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00005127': [201414,
#   201417,
#   201418,
#   20142,
#   201423,
#   201424,
#   201430,
#   20144,
#   20148,
#   20151,
#   201512,
#   201513,
#   201516,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201528,
#   20153,
#   201530,
#   20158],
#  'NCT00005485': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00005757': [201414,
#   201417,
#   201418,
#   20142,
#   201423,
#   201424,
#   201430,
#   20144,
#   20148,
#   20151,
#   201512,
#   201513,
#   201516,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201528,
#   20153,
#   201530,
#   20158],
#  'NCT00077948': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00108381': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00124969': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00129233': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00134160': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00141583': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00143195': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00149227': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00162344': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00166231': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00175279': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00185120': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00190489': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201415,
#   201416,
#   201421,
#   201422,
#   201426,
#   201427,
#   201429,
#   20143,
#   20145,
#   20146,
#   20147,
#   20149,
#   201510,
#   201511,
#   201517,
#   201527,
#   201529,
#   20154,
#   20155,
#   20156,
#   20157,
#   20159],
#  'NCT00202566': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00225355': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00252421': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201415,
#   201416,
#   201421,
#   201422,
#   201426,
#   201427,
#   201429,
#   20143,
#   20145,
#   20146,
#   20147,
#   20149,
#   201510,
#   201511,
#   201517,
#   201527,
#   201529,
#   20154,
#   20155,
#   20156,
#   20157,
#   20159],
#  'NCT00285649': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00337116': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00348803': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00356707': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201415,
#   201416,
#   201421,
#   201422,
#   201426,
#   201427,
#   201429,
#   20143,
#   20145,
#   20146,
#   20147,
#   20149,
#   201510,
#   201511,
#   201517,
#   201527,
#   201529,
#   20154,
#   20155,
#   20156,
#   20157,
#   20159],
#  'NCT00373828': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00375089': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00413712': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00418392': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00424021': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00454662': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00462241': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00479908': [201414,
#   201417,
#   201418,
#   20142,
#   201423,
#   201424,
#   201430,
#   20144,
#   20148,
#   20151,
#   201512,
#   201513,
#   201516,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201528,
#   20153,
#   201530,
#   20158],
#  'NCT00486954': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00536224': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00598728': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00623454': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00624273': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00644319': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00683813': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00705952': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00736333': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00745043': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00752674': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00780260': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201415,
#   201416,
#   201421,
#   201422,
#   201426,
#   201427,
#   201429,
#   20143,
#   20145,
#   20146,
#   20147,
#   20149,
#   201510,
#   201511,
#   201517,
#   201527,
#   201529,
#   20154,
#   20155,
#   20156,
#   20157,
#   20159],
#  'NCT00797953': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00802230': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00808652': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00809029': [201414,
#   201417,
#   201418,
#   20142,
#   201423,
#   201424,
#   201430,
#   20144,
#   20148,
#   20151,
#   201512,
#   201513,
#   201516,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201528,
#   20153,
#   201530,
#   20158],
#  'NCT00832442': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00840593': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00848250': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00883987': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00896285': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00925119': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00932867': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00937365': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201415,
#   201416,
#   201421,
#   201422,
#   201426,
#   201427,
#   201429,
#   20143,
#   20145,
#   20146,
#   20147,
#   20149,
#   201510,
#   201511,
#   201517,
#   201527,
#   201529,
#   20154,
#   20155,
#   20156,
#   20157,
#   20159],
#  'NCT00951808': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00952744': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00974116': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00979199': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00986180': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00992927': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01028534': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01056367': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01080274': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01087723': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01134328': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01162902': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01167205': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01171911': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01175889': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01203696': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01211171': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01216020': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01228123': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01231165': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01250262': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01253486': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01276548': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201415,
#   201416,
#   201421,
#   201422,
#   201426,
#   201427,
#   201429,
#   20143,
#   20145,
#   20146,
#   20147,
#   20149,
#   201510,
#   201511,
#   201517,
#   201527,
#   201529,
#   20154,
#   20155,
#   20156,
#   20157,
#   20159],
#  'NCT01284179': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01290770': [201414,
#   201417,
#   201418,
#   20142,
#   201423,
#   201424,
#   201430,
#   20144,
#   20148,
#   20151,
#   201512,
#   201513,
#   201516,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201528,
#   20153,
#   201530,
#   20158],
#  'NCT01293019': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01332188': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01334203': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01365286': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01397994': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01407146': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01429194': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01444833': [201414,
#   201417,
#   201418,
#   20142,
#   201423,
#   201424,
#   201430,
#   20144,
#   20148,
#   20151,
#   201512,
#   201513,
#   201516,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201528,
#   20153,
#   201530,
#   20158],
#  'NCT01450020': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201415,
#   201416,
#   201421,
#   201422,
#   201426,
#   201427,
#   201429,
#   20143,
#   20145,
#   20146,
#   20147,
#   20149,
#   201510,
#   201511,
#   201517,
#   201527,
#   201529,
#   20154,
#   20155,
#   20156,
#   20157,
#   20159],
#  'NCT01484912': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01494870': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01506999': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01559948': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01561001': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01576978': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201415,
#   201416,
#   201421,
#   201422,
#   201426,
#   201427,
#   201429,
#   20143,
#   20145,
#   20146,
#   20147,
#   20149,
#   201510,
#   201511,
#   201517,
#   201527,
#   201529,
#   20154,
#   20155,
#   20156,
#   20157,
#   20159],
#  'NCT01657136': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01658033': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201415,
#   201416,
#   201421,
#   201422,
# ...
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00494416': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201415,
#   201416,
#   201421,
#   201422,
#   201426,
#   201427,
#   201429,
#   20143,
#   20145,
#   20146,
#   20147,
#   20149,
#   201510,
#   201511,
#   201517,
#   201527,
#   201529,
#   20154,
#   20155,
#   20156,
#   20157,
#   20159],
#  'NCT00497471': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00589329': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201415,
#   201416,
#   201421,
#   201422,
#   201426,
#   201427,
#   201429,
#   20143,
#   20145,
#   20146,
#   20147,
#   20149,
#   201510,
#   201511,
#   201517,
#   201527,
#   201529,
#   20154,
#   20155,
#   20156,
#   20157,
#   20159],
#  'NCT00641823': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00730366': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201415,
#   201416,
#   201421,
#   201422,
#   201426,
#   201427,
#   201429,
#   20143,
#   20145,
#   20146,
#   20147,
#   20149,
#   201510,
#   201511,
#   201517,
#   201527,
#   201529,
#   20154,
#   20155,
#   20156,
#   20157,
#   20159],
#  'NCT00970879': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201415,
#   201416,
#   201421,
#   201422,
#   201426,
#   201427,
#   201429,
#   20143,
#   20145,
#   20146,
#   20147,
#   20149,
#   201510,
#   201511,
#   201517,
#   201527,
#   201529,
#   20154,
#   20155,
#   20156,
#   20157,
#   20159],
#  'NCT00984256': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00984763': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01078779': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01218893': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01236612': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01422954': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01546961': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01557803': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01728701': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01729559': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT01746199': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201415,
#   201416,
#   201421,
#   201422,
#   201426,
#   201427,
#   201429,
#   20143,
#   20145,
#   20146,
#   20147,
#   20149,
#   201510,
#   201511,
#   201517,
#   201527,
#   201529,
#   20154,
#   20155,
#   20156,
#   20157,
#   20159],
#  'NCT02080026': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT02084602': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT02098590': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT02498301': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT02511054': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT02557425': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00026468': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00055848': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00140894': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00224679': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00253812': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00319007': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00485069': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00525655': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00586053': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  'NCT00641147': [20141,
#   201410,
#   201411,
#   201412,
#   201413,
#   201414,
#   201415,
#   201416,
#   201417,
#   201418,
#   20142,
#   201421,
#   201422,
#   201423,
#   201424,
#   201426,
#   201427,
#   201429,
#   20143,
#   201430,
#   20144,
#   20145,
#   20146,
#   20147,
#   20148,
#   20149,
#   20151,
#   201510,
#   201511,
#   201512,
#   201513,
#   201516,
#   201517,
#   201518,
#   20152,
#   201520,
#   201521,
#   201523,
#   201524,
#   201525,
#   201527,
#   201528,
#   201529,
#   20153,
#   201530,
#   20154,
#   20155,
#   20156,
#   20157,
#   20158,
#   20159],
#  ...}

# %% [markdown]
# Awesome!
#
# Although we are only matching based on gender, this is a pretty good first step!
#
#
# ...
#
# You might be wondering, how can we improve from here?

# %% [markdown]
# <img src="https://memegenerator.net/img/instances/75581336.jpg" width="500">

# %% [markdown]
# > Q2: How can we improve from here? What is lacking in our solution?
